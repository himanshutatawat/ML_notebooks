# %%
import pandas as  pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import classification_report
import pandas as pd
import seaborn as sns

# %%
import math
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
# !pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
import tensorflow_addons as tfa
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from __future__ import absolute_import, division, print_function
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history

# %%
def plot_history2(history):
  plt.plot(history.history['mae'])
  plt.plot(history.history['mse'])
  plt.plot(history.history['mape'])
  plt.xlabel("Epochs")
  plt.ylabel('Loss')
  plt.legend(['mae', 'mape', 'mse'])
  plt.show()
# Plot the history

# %%
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/preprocessed_A1_for_A3.csv")

# %%
train.shape
# Out:
# (97023, 9)

# %%
train = train.drop(['Unnamed: 0'], axis = 1)

# %%
train.head()
# Out:
#    fare_amount  passenger_count  H_Distance  Year  Month  Date  Day of Week  \
# 0          4.9                2    1.055053  2012      7    30            0
# 1          6.9                1    2.715959  2011      2    22            1
# 2         14.1                1    5.101370  2010     10     7            3
# 3         12.1                5    4.800593  2009     10     2            4
# 4         21.3                1    7.088301  2009     10     7            2
#
#    Hour
# 0    16
# 1    13
# 2    21
# 3    22
# 4     8

# %%
y_train = train['fare_amount']
x_train = train.drop(['fare_amount'], axis = 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=12345)

# %%
x_train
# Out:
#        passenger_count  H_Distance  Year  Month  Date  Day of Week  Hour
# 50972                1    1.704530  2009      9    19            5    23
# 45752                5    1.633044  2012      2    26            6    19
# 20419                1    2.467301  2010     12    19            6     0
# 14918                2    6.704880  2012      1    15            6     0
# 64644                1    2.391639  2011     10    22            5    12
# ...                ...         ...   ...    ...   ...          ...   ...
# 4094                 6    1.023409  2011     11    21            0    10
# 85412                1    3.246473  2014     10     7            1     8
# 2177                 1    0.893855  2013      8    29            3    13
# 77285                1    0.433110  2013     10    15            1    12
# 86498                1    1.135090  2009      6     5            4    23
#
# [77618 rows x 7 columns]

# %%
y_train
# Out:
# 50972     6.5
# 45752     6.5
# 20419    12.1
# 14918    15.3
# 64644    13.3
#          ...
# 4094      5.7
# 85412    11.0
# 2177      6.5
# 77285     3.5
# 86498     6.1
# Name: fare_amount, Length: 77618, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
trainx_scaled = scaler.transform(x_train)
valx_scaled = scaler.transform(x_val)

# %%
trainx_scaled
# Out:
# array([[-0.52630728, -0.45147765, -1.46875344, ...,  0.38120368,
#          1.01534281,  1.45588725],
#        [ 2.53540665, -0.47189323,  0.14018267, ...,  1.18761496,
#          1.52837134,  0.84060243],
#        [-0.52630728, -0.23363736, -0.9324414 , ...,  0.38120368,
#          1.52837134, -2.08200048],
#        ...,
#        [-0.52630728, -0.68299838,  0.67649471, ...,  1.5332198 ,
#         -0.01071426, -0.0823248 ],
#        [-0.52630728, -0.81458281,  0.67649471, ..., -0.07960277,
#         -1.03677133, -0.23614601],
#        [-0.52630728, -0.61410411, -1.46875344, ..., -1.2316189 ,
#          0.50231428,  1.45588725]])

# %%
trainx_scaled.shape, y_train.shape
# Out:
# ((77618, 7), (77618,))

# %%
# model = Sequential()

# model.add(Dense(16, input_shape=(7,), activation='sigmoid'))
# model.add(Dense(8, activation='sigmoid'))
# model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
# from tensorflow.keras.optimizers import SGD

# opt = SGD(lr=0.01)
# model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
# model = Sequential()
# model.add(Dense(16, input_dim=7, activation='sigmoid'))
# model.add(Dense(8, activation='sigmoid'))
# model.add(Dense(1, activation='sigmoid'))

# opt = SGD(lr=0.5)
# model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
# model.summary()

# %%
# #history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_split=0.10, batch_size=25)
# history = model.fit(trainx_scaled, y_train, epochs=10, verbose=1, validation_data=(valx_scaled,y_val), batch_size=100)

# # make a prediction
# ytest = model.predict(trainx_scaled)

# %%
x_test = x_val
y_test = y_val

# %%
standard_scaler = StandardScaler()
x_train_scaled = pd.DataFrame(
    standard_scaler.fit_transform(x_train),
    columns=x_train.columns)

x_test_scaled = pd.DataFrame(
    standard_scaler.transform(x_test),
    columns = x_test.columns)

# %%
x_test_scaled
# Out:
#        passenger_count  H_Distance      Year     Month      Date  Day of Week  \
# 0             1.004550   -0.775072  1.749119 -1.534055  1.072413     1.528371
# 1            -0.526307    0.121931 -0.396129 -0.660382 -1.346821    -1.549800
# 2            -0.526307    0.522515 -0.396129 -0.951607  1.418018    -1.549800
# 3            -0.526307    0.140199  0.140183  0.795740 -1.577224     1.528371
# 4            -0.526307   -0.434915  1.749119 -0.077933 -0.079603    -1.549800
# ...                ...         ...       ...       ...       ...          ...
# 19400        -0.526307   -0.938275 -0.396129 -0.660382  0.150800     1.528371
# 19401        -0.526307   -0.488088  1.212807 -1.534055 -1.692425    -0.523743
# 19402        -0.526307   -0.512104 -0.932441 -0.951607  1.072413    -0.010714
# 19403        -0.526307   -0.207514  1.212807 -0.951607  0.957212    -1.549800
# 19404        -0.526307    0.596065 -0.932441  0.213291 -1.001216    -0.523743
#
#            Hour
# ...

# %% [markdown]
# A. Create a baseline Neural network with the following specifications.
# 2 hidden layers, each with 16 and 8 neurons respectively. Sigmoid activation, Batch Size=128 for Gradient Descent.

# %%
hidden_units1 = 16
hidden_units2 = 8

learning_rate = 0.001

# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='sigmoid'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='sigmoid'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
  
# build the model
model = build_model_using_sequential()

# %%
# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=['mse','mae','mape'], 
    optimizer=SGD(learning_rate=learning_rate), 
    metrics=['mse','mae','mape']
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=150, 
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/150
# 486/486 [==============================] - 8s 7ms/step - loss: 97.3779 - mse: 97.3779 - mae: 6.1110 - mape: 57.9328 - val_loss: 80.0071 - val_mse: 80.0071 - val_mae: 5.5195 - val_mape: 59.3426
# Epoch 2/150
# 486/486 [==============================] - 3s 6ms/step - loss: 78.0264 - mse: 78.0264 - mae: 5.6046 - mape: 60.8574 - val_loss: 75.3236 - val_mse: 75.3236 - val_mae: 5.4186 - val_mape: 59.5890
# Epoch 3/150
# 486/486 [==============================] - 3s 6ms/step - loss: 72.4101 - mse: 72.4101 - mae: 5.3786 - mape: 58.6651 - val_loss: 67.3202 - val_mse: 67.3202 - val_mae: 4.9944 - val_mape: 54.3582
# Epoch 4/150
# 486/486 [==============================] - 3s 6ms/step - loss: 61.4443 - mse: 61.4443 - mae: 4.8213 - mape: 52.0033 - val_loss: 52.7200 - val_mse: 52.7200 - val_mae: 4.2214 - val_mape: 45.6962
# Epoch 5/150
# 287/486 [================>.............] - ETA: 0s - loss: 50.6724 - mse: 50.6724 - mae: 4.2061 - mape: 44.2418
# ...

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'mape', 'val_loss', 'val_mse', 'val_mae', 'val_mape'])

# %%
plot_history(history, 'loss')

# %%
plot_history2(history)

# %%
x_test['prediction'] = model.predict(x_test_scaled)

# %%
y_test
# Out:
# 70384     4.5
# 33635     9.3
# 63395    10.1
# 75838    11.7
# 33441     9.0
#          ...
# 70148     6.5
# 7834      5.5
# 39104     6.9
# 51457     8.0
# 58034    10.9
# Name: fare_amount, Length: 19405, dtype: float64

# %%
# Calculation of Mean Squared Error (MSE)
mean_squared_error(y_test,x_test['prediction'])
# Out:
# 14.059799484055189

# %% [markdown]
# B. Experiment with number of layers and neurons per layer to increase the performance metrics.

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.5
  batch_s = 128
  epp = 150

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='sigmoid'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='sigmoid'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='sigmoid'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=SGD(learning_rate=learning_rate),
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
# Out:
# Epoch 1/150
# 486/486 [==============================] - 3s 6ms/step - loss: 0.2885 - mean_squared_logarithmic_error: 0.2884 - val_loss: 0.1433 - val_mean_squared_logarithmic_error: 0.1432
# Epoch 2/150
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0941 - mean_squared_logarithmic_error: 0.0940 - val_loss: 0.0624 - val_mean_squared_logarithmic_error: 0.0624
# Epoch 3/150
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0767 - mean_squared_logarithmic_error: 0.0767 - val_loss: 0.0602 - val_mean_squared_logarithmic_error: 0.0602
# Epoch 4/150
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0749 - mean_squared_logarithmic_error: 0.0749 - val_loss: 0.0614 - val_mean_squared_logarithmic_error: 0.0614
# Epoch 5/150
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0729 - mean_squared_logarithmic_error: 0.0729 - val_loss: 0.0600 - val_mean_squared_logarithmic_error: 0.0601
# Epoch 6/150
# ...

# %%
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# 14.397345968803068

# %%
y_test,pred
# Out:
# (70384     4.5
#  33635     9.3
#  63395    10.1
#  75838    11.7
#  33441     9.0
#           ...
#  70148     6.5
#  7834      5.5
#  39104     6.9
#  51457     8.0
#  58034    10.9
#  Name: fare_amount, Length: 19405, dtype: float64, array([[ 5.256871 ],
#         [10.784994 ],
#         [13.649561 ],
#         ...,
#         [ 5.9053307],
#         [ 9.802963 ],
#         [13.781097 ]], dtype=float32))

# %% [markdown]
# C. Experiment with activation functions

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.5
  batch_s = 128
  epp = 25

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=SGD(learning_rate=learning_rate),
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
# Out:
# Epoch 1/25
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0886 - mean_squared_logarithmic_error: 0.0885 - val_loss: 0.0527 - val_mean_squared_logarithmic_error: 0.0527
# Epoch 2/25
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0565 - mean_squared_logarithmic_error: 0.0566 - val_loss: 0.0561 - val_mean_squared_logarithmic_error: 0.0561
# Epoch 3/25
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0554 - mean_squared_logarithmic_error: 0.0554 - val_loss: 0.0516 - val_mean_squared_logarithmic_error: 0.0517
# Epoch 4/25
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0543 - mean_squared_logarithmic_error: 0.0543 - val_loss: 0.0514 - val_mean_squared_logarithmic_error: 0.0515
# Epoch 5/25
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0540 - mean_squared_logarithmic_error: 0.0540 - val_loss: 0.0531 - val_mean_squared_logarithmic_error: 0.0531
# Epoch 6/25
# ...

# %%
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# 13.047932698251842

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 40

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.1),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.1),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=SGD(learning_rate=learning_rate),
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
# Out:
# Epoch 1/40
# 486/486 [==============================] - 3s 6ms/step - loss: 0.1002 - mean_squared_logarithmic_error: 0.1000 - val_loss: 0.0531 - val_mean_squared_logarithmic_error: 0.0532
# Epoch 2/40
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0559 - mean_squared_logarithmic_error: 0.0560 - val_loss: 0.0535 - val_mean_squared_logarithmic_error: 0.0536
# Epoch 3/40
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0547 - mean_squared_logarithmic_error: 0.0547 - val_loss: 0.0534 - val_mean_squared_logarithmic_error: 0.0534
# Epoch 4/40
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0542 - mean_squared_logarithmic_error: 0.0542 - val_loss: 0.0516 - val_mean_squared_logarithmic_error: 0.0517
# Epoch 5/40
# 486/486 [==============================] - 4s 9ms/step - loss: 0.0537 - mean_squared_logarithmic_error: 0.0537 - val_loss: 0.0512 - val_mean_squared_logarithmic_error: 0.0512
# Epoch 6/40
# ...

# %%
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# 12.564112689271802

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.01
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='tanh'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='tanh'),
    Dropout(0.1),
    Dense(hidden_units3, kernel_initializer='normal', activation='tanh'),
    Dropout(0.1),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=SGD(learning_rate=learning_rate),
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
# Out:
# Epoch 1/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.7026 - mean_squared_logarithmic_error: 0.7017 - val_loss: 0.1713 - val_mean_squared_logarithmic_error: 0.1712
# Epoch 2/100
# 486/486 [==============================] - 2s 4ms/step - loss: 0.1340 - mean_squared_logarithmic_error: 0.1338 - val_loss: 0.1036 - val_mean_squared_logarithmic_error: 0.1036
# Epoch 3/100
# 486/486 [==============================] - 2s 4ms/step - loss: 0.0947 - mean_squared_logarithmic_error: 0.0946 - val_loss: 0.0870 - val_mean_squared_logarithmic_error: 0.0871
# Epoch 4/100
# 486/486 [==============================] - 2s 4ms/step - loss: 0.0874 - mean_squared_logarithmic_error: 0.0874 - val_loss: 0.0836 - val_mean_squared_logarithmic_error: 0.0837
# Epoch 5/100
# 486/486 [==============================] - 2s 4ms/step - loss: 0.0851 - mean_squared_logarithmic_error: 0.0850 - val_loss: 0.0816 - val_mean_squared_logarithmic_error: 0.0817
# Epoch 6/100
# ...

# %%
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# 21.99813595770572

# %% [markdown]
# D

# %% [markdown]
# Experiment with regularization techniques: Dropout rate

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 20

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=SGD(learning_rate=learning_rate),
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
# Out:
# Epoch 1/20
# 486/486 [==============================] - 5s 7ms/step - loss: 0.1156 - mean_squared_logarithmic_error: 0.1154 - val_loss: 0.0532 - val_mean_squared_logarithmic_error: 0.0532
# Epoch 2/20
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0585 - mean_squared_logarithmic_error: 0.0585 - val_loss: 0.0526 - val_mean_squared_logarithmic_error: 0.0526
# Epoch 3/20
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0570 - mean_squared_logarithmic_error: 0.0576 - val_loss: 0.0549 - val_mean_squared_logarithmic_error: 0.0550
# Epoch 4/20
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0564 - mean_squared_logarithmic_error: 0.0564 - val_loss: 0.0517 - val_mean_squared_logarithmic_error: 0.0518
# Epoch 5/20
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0557 - mean_squared_logarithmic_error: 0.0557 - val_loss: 0.0511 - val_mean_squared_logarithmic_error: 0.0512
# Epoch 6/20
# ...

# %%
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# 12.548155379448765

# %% [markdown]
# Experiment with regularization techniques: Early stopping

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.00005,
    patience=5,
    verbose=0,
    mode='min',
    baseline=None,
    restore_best_weights=False
)

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=SGD(learning_rate=learning_rate),
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
# Out:
# Epoch 1/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.1124 - mean_squared_logarithmic_error: 0.1123 - val_loss: 0.0531 - val_mean_squared_logarithmic_error: 0.0532
# Epoch 2/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0577 - mean_squared_logarithmic_error: 0.0577 - val_loss: 0.0521 - val_mean_squared_logarithmic_error: 0.0522
# Epoch 3/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0565 - mean_squared_logarithmic_error: 0.0565 - val_loss: 0.0531 - val_mean_squared_logarithmic_error: 0.0531
# Epoch 4/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0554 - mean_squared_logarithmic_error: 0.0553 - val_loss: 0.0513 - val_mean_squared_logarithmic_error: 0.0513
# Epoch 5/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0549 - mean_squared_logarithmic_error: 0.0549 - val_loss: 0.0519 - val_mean_squared_logarithmic_error: 0.0519
# Epoch 6/100
# ...

# %%
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# 12.481786897279466

# %% [markdown]
# E. Experiment with at least 2 more Optimizers

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer='adam',
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# Epoch 1/100
# 486/486 [==============================] - 4s 7ms/step - loss: 0.2851 - mean_squared_logarithmic_error: 0.2846 - val_loss: 0.0605 - val_mean_squared_logarithmic_error: 0.0606
# Epoch 2/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0628 - mean_squared_logarithmic_error: 0.0628 - val_loss: 0.0530 - val_mean_squared_logarithmic_error: 0.0531
# Epoch 3/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0592 - mean_squared_logarithmic_error: 0.0591 - val_loss: 0.0521 - val_mean_squared_logarithmic_error: 0.0522
# Epoch 4/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0581 - mean_squared_logarithmic_error: 0.0581 - val_loss: 0.0510 - val_mean_squared_logarithmic_error: 0.0510
# Epoch 5/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0566 - mean_squared_logarithmic_error: 0.0566 - val_loss: 0.0506 - val_mean_squared_logarithmic_error: 0.0507
# Epoch 6/100
# ...

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# Epoch 1/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.1045 - mean_squared_logarithmic_error: 0.1044 - val_loss: 0.0536 - val_mean_squared_logarithmic_error: 0.0537
# Epoch 2/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0584 - mean_squared_logarithmic_error: 0.0585 - val_loss: 0.0526 - val_mean_squared_logarithmic_error: 0.0526
# Epoch 3/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0570 - mean_squared_logarithmic_error: 0.0570 - val_loss: 0.0523 - val_mean_squared_logarithmic_error: 0.0524
# Epoch 4/100
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0561 - mean_squared_logarithmic_error: 0.0561 - val_loss: 0.0519 - val_mean_squared_logarithmic_error: 0.0519
# Epoch 5/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0555 - mean_squared_logarithmic_error: 0.0555 - val_loss: 0.0512 - val_mean_squared_logarithmic_error: 0.0513
# Epoch 6/100
# ...

# %%
adamax = tf.keras.optimizers.Adamax(learning_rate=0.001, 
                                   beta_1=0.9, 
                                   beta_2=0.999, 
                                   epsilon=1e-07,
                                   name='Adamax')

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=adamax,
      metrics=[msle]
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# Epoch 1/100
# 486/486 [==============================] - 5s 6ms/step - loss: 0.4233 - mean_squared_logarithmic_error: 0.4228 - val_loss: 0.0761 - val_mean_squared_logarithmic_error: 0.0761
# Epoch 2/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0762 - mean_squared_logarithmic_error: 0.0761 - val_loss: 0.0633 - val_mean_squared_logarithmic_error: 0.0633
# Epoch 3/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0656 - mean_squared_logarithmic_error: 0.0656 - val_loss: 0.0560 - val_mean_squared_logarithmic_error: 0.0560
# Epoch 4/100
# 486/486 [==============================] - 3s 6ms/step - loss: 0.0606 - mean_squared_logarithmic_error: 0.0606 - val_loss: 0.0537 - val_mean_squared_logarithmic_error: 0.0538
# Epoch 5/100
# 486/486 [==============================] - 3s 5ms/step - loss: 0.0592 - mean_squared_logarithmic_error: 0.0592 - val_loss: 0.0527 - val_mean_squared_logarithmic_error: 0.0527
# Epoch 6/100
# ...

# %% [markdown]
# Three metric

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss=msle, 
      optimizer=adamax,
      metrics=[msle,'mse','mae','mape']
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mean_squared_logarithmic_error')
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# Epoch 1/100
# 486/486 [==============================] - 4s 5ms/step - loss: 0.3893 - mean_squared_logarithmic_error: 0.3887 - mse: 38.7325 - mae: 3.6968 - mape: 35.1349 - val_loss: 0.0740 - val_mean_squared_logarithmic_error: 0.0740 - val_mse: 14.9865 - val_mae: 2.4089 - val_mape: 23.7639
# Epoch 2/100
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0740 - mean_squared_logarithmic_error: 0.0742 - mse: 15.6094 - mae: 2.4433 - mape: 23.5469 - val_loss: 0.0615 - val_mean_squared_logarithmic_error: 0.0615 - val_mse: 13.4895 - val_mae: 2.1910 - val_mape: 20.8846
# Epoch 3/100
# 486/486 [==============================] - 2s 5ms/step - loss: 0.0653 - mean_squared_logarithmic_error: 0.0655 - mse: 14.4947 - mae: 2.2955 - mape: 21.5808 - val_loss: 0.0557 - val_mean_squared_logarithmic_error: 0.0558 - val_mse: 12.9304 - val_mae: 2.0521 - val_mape: 18.8100
# Epoch 4/100
# ...

# %%
history2.history.keys()
# Out:
# dict_keys(['loss', 'mean_squared_logarithmic_error', 'mse', 'mae', 'mape', 'val_loss', 'val_mean_squared_logarithmic_error', 'val_mse', 'val_mae', 'val_mape'])

# %%
plot_history2(history2)

# %%
mse = mean_squared_error(y_test,pred) * 0.01
mae = mean_absolute_error(y_test,pred) * 0.01
mse, mae
# Out:
# (0.12727980650809875, 0.019374954694066273)

# %%
pred.shape[0]
# Out:
# 19405

# %%
# binomial confidence interval
from math import sqrt

# We can calculate the 95% confidence interval (z = 1.96) as follows:
interval = 1.96 * sqrt( (mae * (1 - mae)) / pred.shape[0])
print('%.3f' % interval)
# Out:
# 0.002

# %%
from statsmodels.stats.proportion import proportion_confint

lower, upper = proportion_confint(97, 100, 0.05)
print('lower=%.3f, upper=%.3f' % (lower, upper))
# Out:
# lower=0.937, upper=1.000

# %%
import seaborn as sns

# %%
sns.histplot(pred)

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss='mse', 
      optimizer=adamax,
      metrics=['mse']
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mse')
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# Epoch 1/100
# 486/486 [==============================] - 3s 5ms/step - loss: 41.4467 - mse: 41.4467 - val_loss: 13.4940 - val_mse: 13.4940
# Epoch 2/100
# 486/486 [==============================] - 3s 5ms/step - loss: 14.4623 - mse: 14.4623 - val_loss: 12.5243 - val_mse: 12.5243
# Epoch 3/100
# 486/486 [==============================] - 4s 9ms/step - loss: 13.7393 - mse: 13.7393 - val_loss: 12.2156 - val_mse: 12.2156
# Epoch 4/100
# 486/486 [==============================] - 3s 7ms/step - loss: 13.6278 - mse: 13.6278 - val_loss: 12.2275 - val_mse: 12.2275
# Epoch 5/100
# 486/486 [==============================] - 3s 7ms/step - loss: 13.2836 - mse: 13.2836 - val_loss: 12.2344 - val_mse: 12.2344
# Epoch 6/100
# 486/486 [==============================] - 3s 6ms/step - loss: 13.3374 - mse: 13.3374 - val_loss: 12.1090 - val_mse: 12.1090
# Epoch 7/100
# 486/486 [==============================] - 3s 6ms/step - loss: 13.1242 - mse: 13.1242 - val_loss: 11.8419 - val_mse: 11.8419
# ...

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss='mae', 
      optimizer=adamax,
      metrics=['mae']
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mae')
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# Epoch 1/100
# 486/486 [==============================] - 3s 5ms/step - loss: 3.6770 - mae: 3.6770 - val_loss: 2.0849 - val_mae: 2.0849
# Epoch 2/100
# 486/486 [==============================] - 2s 4ms/step - loss: 2.2122 - mae: 2.2122 - val_loss: 1.9935 - val_mae: 1.9935
# Epoch 3/100
# 486/486 [==============================] - 2s 4ms/step - loss: 2.1600 - mae: 2.1600 - val_loss: 1.9658 - val_mae: 1.9658
# Epoch 4/100
# 486/486 [==============================] - 2s 4ms/step - loss: 2.1379 - mae: 2.1379 - val_loss: 1.9475 - val_mae: 1.9475
# Epoch 5/100
# 486/486 [==============================] - 2s 5ms/step - loss: 2.1120 - mae: 2.1120 - val_loss: 1.9356 - val_mae: 1.9356
# Epoch 6/100
# 486/486 [==============================] - 2s 5ms/step - loss: 2.0982 - mae: 2.0982 - val_loss: 1.9294 - val_mae: 1.9294
# Epoch 7/100
# 486/486 [==============================] - 2s 4ms/step - loss: 2.0826 - mae: 2.0826 - val_loss: 1.9112 - val_mae: 1.9112
# Epoch 8/100
# ...

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential():
  hidden_units1 = 150
  hidden_units2 = 120
  hidden_units3 = 130
  learning_rate = 0.25
  batch_s = 128
  epp = 100

  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(1, kernel_initializer='normal', activation='linear')])

  # loss function
  msle = MeanSquaredLogarithmicError()
  model.compile(
      loss='mape', 
      optimizer=adamax,
      metrics=['mape']
  )

  # train the model
  history = model.fit(
      x_train_scaled.values, 
      y_train.values, 
      epochs=epp, 
      batch_size=batch_s,
      validation_split=0.2,
      callbacks=[callback]
  )

  return model,history
  
# build the model
model,history2 = build_model_using_sequential()
plot_history(history2, 'mape')
pred = model.predict(x_test_scaled)
mean_squared_error(y_test,pred)
# Out:
# Epoch 1/100
# 486/486 [==============================] - 3s 5ms/step - loss: 32.9253 - mape: 32.9253 - val_loss: 18.3338 - val_mape: 18.3338
# Epoch 2/100
# 486/486 [==============================] - 2s 4ms/step - loss: 19.5156 - mape: 19.5156 - val_loss: 17.2730 - val_mape: 17.2730
# Epoch 3/100
# 486/486 [==============================] - 2s 4ms/step - loss: 18.9469 - mape: 18.9469 - val_loss: 17.0656 - val_mape: 17.0656
# Epoch 4/100
# 486/486 [==============================] - 2s 4ms/step - loss: 18.6717 - mape: 18.6717 - val_loss: 17.0345 - val_mape: 17.0345
# Epoch 5/100
# 486/486 [==============================] - 2s 4ms/step - loss: 18.3976 - mape: 18.3976 - val_loss: 16.9555 - val_mape: 16.9555
# Epoch 6/100
# 486/486 [==============================] - 2s 4ms/step - loss: 18.3302 - mape: 18.3302 - val_loss: 16.8551 - val_mape: 16.8551
# Epoch 7/100
# ...

# %%
# Import pandas library
import pandas as pd
  
# initialize list of lists
data = [['tom', 10], ['nick', 15], ['juli', 14]]
  
# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['Name', 'Age'])
  
# print dataframe.
df

# %% [markdown]
# Part B

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_data = np.load('/content/drive/MyDrive/Colab Notebooks/data/Preprocessed_data_A2_c.npz')

train = train_data["x_train"]
label_train = train_data["y_train"]
test = train_data["x_test"]
label_test = train_data["y_test"]

# %%
# train_data = np.load('/content/drive/MyDrive/Colab Notebooks/data/Preprocessed_data_A2_for_A3.npz')

# train = train_data["x_train"]
# label_train = train_data["y_train"]
# test = train_data["x_test"]
# label_test = train_data["y_test"]

# %%
train.shape
# Out:
# (2939, 128, 128, 3)

# %% [markdown]
# A. Create a baseline Neural network with the following specifications.
# 4 hidden layers, each with 1024, 256, 64 and 7 neurons respectively followed by Softmax function respectively. Sigmoid activation, Batch Size=128 for Gradient Descent.

# %%
def output(pred):
  y_hat = []
  for i in pred:
    idx = np.where(i==max(i))
    y_hat.append(idx[0][0])

  y_hat = np.array(y_hat)
  return y_hat

# %%
learning_rate = 0.5
epp = 100

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 64
  hidden_units4 = 7
  learning_rate = 0.5
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='sigmoid'),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(64, activation='sigmoid'),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
# Out:
# Epoch 1/100
#  1/19 [>.............................] - ETA: 31:01 - loss: 1.9857 - accuracy: 0.1172

# %%
history2.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plot_history(history2, 'loss')

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4483 - accuracy: 0.9077
# Test accuracy: 0.9077134728431702

# %% [markdown]
# B. Experiment with number of layers and neurons per layer to increase the performance metrics.

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.5
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='sigmoid'),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 119ms/step - loss: 2.2144 - accuracy: 0.1829 - val_loss: 1.9197 - val_accuracy: 0.1888
# Epoch 2/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.8923 - accuracy: 0.2127 - val_loss: 1.9400 - val_accuracy: 0.1718
# Epoch 3/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.8941 - accuracy: 0.2093 - val_loss: 1.8989 - val_accuracy: 0.1718
# Epoch 4/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.8630 - accuracy: 0.2442 - val_loss: 2.0207 - val_accuracy: 0.1820
# Epoch 5/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.8359 - accuracy: 0.2739 - val_loss: 2.1551 - val_accuracy: 0.1837
# Epoch 6/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.8141 - accuracy: 0.2756 - val_loss: 1.6220 - val_accuracy: 0.3401
# Epoch 7/100
# ...

# %%
plot_history(history2, 'loss')

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3879 - accuracy: 0.9174
# Test accuracy: 0.9173553586006165

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.5
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='sigmoid'),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(16, activation='sigmoid'),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 119ms/step - loss: 1.9103 - accuracy: 0.2097 - val_loss: 1.9090 - val_accuracy: 0.2194
# Epoch 2/100
# 19/19 [==============================] - 2s 110ms/step - loss: 1.8899 - accuracy: 0.2174 - val_loss: 1.8885 - val_accuracy: 0.1718
# Epoch 3/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.8889 - accuracy: 0.2063 - val_loss: 1.8895 - val_accuracy: 0.3214
# Epoch 4/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.8612 - accuracy: 0.2654 - val_loss: 1.7522 - val_accuracy: 0.3401
# Epoch 5/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.7930 - accuracy: 0.2850 - val_loss: 1.7409 - val_accuracy: 0.3061
# Epoch 6/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.6960 - accuracy: 0.3462 - val_loss: 1.5886 - val_accuracy: 0.3622
# Epoch 7/100
# ...

# %%
plot_history(history2, 'loss')

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4003 - accuracy: 0.9174
# Test accuracy: 0.9173553586006165

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.5
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='sigmoid'),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(64, activation='sigmoid'),
    keras.layers.Dense(64, activation='sigmoid'),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 114ms/step - loss: 1.9917 - accuracy: 0.1914 - val_loss: 1.9952 - val_accuracy: 0.1514
# Epoch 2/100
# 19/19 [==============================] - 2s 104ms/step - loss: 1.9192 - accuracy: 0.2008 - val_loss: 1.9646 - val_accuracy: 0.2194
# Epoch 3/100
# 19/19 [==============================] - 2s 105ms/step - loss: 1.9060 - accuracy: 0.2127 - val_loss: 1.9074 - val_accuracy: 0.2194
# Epoch 4/100
# 19/19 [==============================] - 2s 105ms/step - loss: 1.8917 - accuracy: 0.2097 - val_loss: 1.9274 - val_accuracy: 0.2194
# Epoch 5/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.9006 - accuracy: 0.2114 - val_loss: 1.8983 - val_accuracy: 0.1514
# Epoch 6/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.9020 - accuracy: 0.2105 - val_loss: 1.9914 - val_accuracy: 0.1718
# Epoch 7/100
# ...

# %%
plot_history(history2, 'loss')

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5182 - accuracy: 0.8526
# Test accuracy: 0.852617084980011

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# C. Experiment with activation functions

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.05
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 116ms/step - loss: 1.8833 - accuracy: 0.2284 - val_loss: 2.0547 - val_accuracy: 0.1514
# Epoch 2/100
# 19/19 [==============================] - 2s 105ms/step - loss: 1.9280 - accuracy: 0.2157 - val_loss: 1.9061 - val_accuracy: 0.2194
# Epoch 3/100
# 19/19 [==============================] - 2s 104ms/step - loss: 1.8902 - accuracy: 0.2195 - val_loss: 1.8826 - val_accuracy: 0.2194
# Epoch 4/100
# 19/19 [==============================] - 2s 104ms/step - loss: 1.8671 - accuracy: 0.2280 - val_loss: 1.8548 - val_accuracy: 0.2245
# Epoch 5/100
# 19/19 [==============================] - 2s 105ms/step - loss: 1.7827 - accuracy: 0.2909 - val_loss: 1.6859 - val_accuracy: 0.3333
# Epoch 6/100
# 19/19 [==============================] - 2s 105ms/step - loss: 1.6106 - accuracy: 0.3450 - val_loss: 1.4150 - val_accuracy: 0.4201
# Epoch 7/100
# ...

# %%
plot_history(history2, 'loss')

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='tanh'),
    keras.layers.Dense(256, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 114ms/step - loss: 1.9373 - accuracy: 0.2161 - val_loss: 1.8876 - val_accuracy: 0.2194
# Epoch 2/100
# 19/19 [==============================] - 2s 103ms/step - loss: 1.8863 - accuracy: 0.2191 - val_loss: 1.8845 - val_accuracy: 0.2194
# Epoch 3/100
# 19/19 [==============================] - 2s 104ms/step - loss: 1.8839 - accuracy: 0.2152 - val_loss: 1.8816 - val_accuracy: 0.1837
# Epoch 4/100
# 19/19 [==============================] - 2s 103ms/step - loss: 1.8445 - accuracy: 0.2365 - val_loss: 1.7556 - val_accuracy: 0.2466
# Epoch 5/100
# 19/19 [==============================] - 2s 104ms/step - loss: 1.7435 - accuracy: 0.2837 - val_loss: 1.6959 - val_accuracy: 0.3316
# Epoch 6/100
# 19/19 [==============================] - 2s 104ms/step - loss: 1.7562 - accuracy: 0.2884 - val_loss: 1.9424 - val_accuracy: 0.2194
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6347 - accuracy: 0.8512
# Test accuracy: 0.8512396812438965

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 116ms/step - loss: 1.9386 - accuracy: 0.1752 - val_loss: 1.9374 - val_accuracy: 0.1718
# Epoch 2/100
# 19/19 [==============================] - 2s 106ms/step - loss: 1.9242 - accuracy: 0.1740 - val_loss: 1.9249 - val_accuracy: 0.1599
# Epoch 3/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9101 - accuracy: 0.1778 - val_loss: 1.9106 - val_accuracy: 0.2194
# Epoch 4/100
# 19/19 [==============================] - 2s 106ms/step - loss: 1.8974 - accuracy: 0.1706 - val_loss: 1.9026 - val_accuracy: 0.1156
# Epoch 5/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.8774 - accuracy: 0.1578 - val_loss: 1.8791 - val_accuracy: 0.1905
# Epoch 6/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.8472 - accuracy: 0.1906 - val_loss: 1.8405 - val_accuracy: 0.2075
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2972 - accuracy: 0.9187
# Test accuracy: 0.918732762336731

# %% [markdown]
# D. Experiment with regularization techniques: Early stopping, Dropout rate

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(256, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(128, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(16, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 117ms/step - loss: 1.9405 - accuracy: 0.1769 - val_loss: 1.9334 - val_accuracy: 0.1718
# Epoch 2/100
# 19/19 [==============================] - 2s 106ms/step - loss: 1.9300 - accuracy: 0.1833 - val_loss: 1.9241 - val_accuracy: 0.1718
# Epoch 3/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9203 - accuracy: 0.1816 - val_loss: 1.9134 - val_accuracy: 0.1718
# Epoch 4/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9109 - accuracy: 0.1821 - val_loss: 1.9080 - val_accuracy: 0.1718
# Epoch 5/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9074 - accuracy: 0.1944 - val_loss: 1.9019 - val_accuracy: 0.1718
# Epoch 6/100
# 19/19 [==============================] - 2s 115ms/step - loss: 1.9035 - accuracy: 0.1897 - val_loss: 1.8958 - val_accuracy: 0.2942
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 14ms/step - loss: 0.2698 - accuracy: 0.9242
# Test accuracy: 0.9242424368858337

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    Dropout(0.3),
    keras.layers.Dense(256, activation='relu'),
    Dropout(0.3),
    keras.layers.Dense(128, activation='relu'),
    Dropout(0.3),
    keras.layers.Dense(16, activation='relu'),
    Dropout(0.3),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 117ms/step - loss: 1.9450 - accuracy: 0.1701 - val_loss: 1.9384 - val_accuracy: 0.2194
# Epoch 2/100
# 19/19 [==============================] - 2s 106ms/step - loss: 1.9360 - accuracy: 0.2237 - val_loss: 1.9288 - val_accuracy: 0.2194
# Epoch 3/100
# 19/19 [==============================] - 2s 111ms/step - loss: 1.9273 - accuracy: 0.2259 - val_loss: 1.9166 - val_accuracy: 0.2194
# Epoch 4/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.9149 - accuracy: 0.2237 - val_loss: 1.8940 - val_accuracy: 0.2653
# Epoch 5/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.8941 - accuracy: 0.2565 - val_loss: 1.8522 - val_accuracy: 0.2823
# Epoch 6/100
# 19/19 [==============================] - 2s 109ms/step - loss: 1.8665 - accuracy: 0.2633 - val_loss: 1.7968 - val_accuracy: 0.3248
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4761 - accuracy: 0.8650
# Test accuracy: 0.8650137782096863

# %%
pred = model.predict(test)
y_hat = output(pred)

labels = np.arange(7)
train_categories = ['airplane','motorbus','boat','truck','bicycle','motorcycle','seaplane']

clf_report = classification_report(label_test,
                                   y_hat,
                                   labels=labels,
                                   target_names=train_categories,
                                   output_dict=True)

# .iloc[:-1, :] to exclude support
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True)

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    Dropout(0.05),
    keras.layers.Dense(256, activation='relu'),
    Dropout(0.05),
    keras.layers.Dense(128, activation='relu'),
    Dropout(0.05),
    keras.layers.Dense(16, activation='relu'),
    Dropout(0.05),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 118ms/step - loss: 1.9318 - accuracy: 0.1821 - val_loss: 1.9199 - val_accuracy: 0.1888
# Epoch 2/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9037 - accuracy: 0.2016 - val_loss: 1.8884 - val_accuracy: 0.1888
# Epoch 3/100
# 19/19 [==============================] - 2s 106ms/step - loss: 1.8658 - accuracy: 0.2029 - val_loss: 1.8446 - val_accuracy: 0.1888
# Epoch 4/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.8226 - accuracy: 0.2416 - val_loss: 1.8252 - val_accuracy: 0.2296
# Epoch 5/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.7841 - accuracy: 0.3237 - val_loss: 1.7848 - val_accuracy: 0.4371
# Epoch 6/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.7539 - accuracy: 0.3590 - val_loss: 1.7459 - val_accuracy: 0.3588
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2742 - accuracy: 0.9160
# Test accuracy: 0.915977954864502

# %%
pred = model.predict(test)
y_hat = output(pred)

labels = np.arange(7)
train_categories = ['airplane','motorbus','boat','truck','bicycle','motorcycle','seaplane']

clf_report = classification_report(label_test,
                                   y_hat,
                                   labels=labels,
                                   target_names=train_categories,
                                   output_dict=True)

# .iloc[:-1, :] to exclude support
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True)

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.00005,
    patience=10,
    verbose=0,
    mode='min',
    baseline=None,
    restore_best_weights=False
)

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(256, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(128, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(16, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=tf.compat.v1.train.GradientDescentOptimizer(learning_rate, name = 'GradientDescent'),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s,
                      callbacks=[callback]
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 125ms/step - loss: 1.9393 - accuracy: 0.1608 - val_loss: 1.9292 - val_accuracy: 0.1888
# Epoch 2/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9268 - accuracy: 0.1986 - val_loss: 1.9102 - val_accuracy: 0.1888
# Epoch 3/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9055 - accuracy: 0.2080 - val_loss: 1.8756 - val_accuracy: 0.1888
# Epoch 4/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.8607 - accuracy: 0.2382 - val_loss: 1.8185 - val_accuracy: 0.3197
# Epoch 5/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.8046 - accuracy: 0.2582 - val_loss: 1.7228 - val_accuracy: 0.3350
# Epoch 6/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.7312 - accuracy: 0.3288 - val_loss: 1.6467 - val_accuracy: 0.3673
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2521 - accuracy: 0.9284
# Test accuracy: 0.9283746480941772

# %%
pred = model.predict(test)
y_hat = output(pred)

labels = np.arange(7)
train_categories = ['airplane','motorbus','boat','truck','bicycle','motorcycle','seaplane']

clf_report = classification_report(label_test,
                                   y_hat,
                                   labels=labels,
                                   target_names=train_categories,
                                   output_dict=True)

# .iloc[:-1, :] to exclude support
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True)

# %% [markdown]
# E. Experiment with at least 2 more Optimizers

# %%
adamax = tf.keras.optimizers.Adamax(learning_rate=0.001, 
                                   beta_1=0.9, 
                                   beta_2=0.999, 
                                   epsilon=1e-07,
                                   name='Adamax')

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(256, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(128, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(16, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=SGD(learning_rate=learning_rate),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s,
                      callbacks=[callback]
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 116ms/step - loss: 1.9416 - accuracy: 0.1786 - val_loss: 1.9344 - val_accuracy: 0.1888
# Epoch 2/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.9325 - accuracy: 0.1829 - val_loss: 1.9237 - val_accuracy: 0.1888
# Epoch 3/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.9236 - accuracy: 0.1982 - val_loss: 1.9168 - val_accuracy: 0.1888
# Epoch 4/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.9173 - accuracy: 0.2008 - val_loss: 1.9036 - val_accuracy: 0.1888
# Epoch 5/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.9064 - accuracy: 0.2178 - val_loss: 1.8940 - val_accuracy: 0.1888
# Epoch 6/100
# 19/19 [==============================] - 2s 109ms/step - loss: 1.8927 - accuracy: 0.2420 - val_loss: 1.8656 - val_accuracy: 0.3197
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.2870 - accuracy: 0.9215
# Test accuracy: 0.9214876294136047

# %%
pred = model.predict(test)
y_hat = output(pred)

labels = np.arange(7)
train_categories = ['airplane','motorbus','boat','truck','bicycle','motorcycle','seaplane']

clf_report = classification_report(label_test,
                                   y_hat,
                                   labels=labels,
                                   target_names=train_categories,
                                   output_dict=True)

# .iloc[:-1, :] to exclude support
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True)

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(256, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(128, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(16, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s,
                      callbacks=[callback]
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 117ms/step - loss: 1.9338 - accuracy: 0.1791 - val_loss: 1.9248 - val_accuracy: 0.1905
# Epoch 2/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.7903 - accuracy: 0.2633 - val_loss: 1.4924 - val_accuracy: 0.3452
# Epoch 3/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.4638 - accuracy: 0.3922 - val_loss: 1.2891 - val_accuracy: 0.5221
# Epoch 4/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.2340 - accuracy: 0.5355 - val_loss: 1.0977 - val_accuracy: 0.6156
# Epoch 5/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.0698 - accuracy: 0.6325 - val_loss: 1.1080 - val_accuracy: 0.6565
# Epoch 6/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.9688 - accuracy: 0.6627 - val_loss: 0.8486 - val_accuracy: 0.7432
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5468 - accuracy: 0.8788
# Test accuracy: 0.8787878751754761

# %%
pred = model.predict(test)
y_hat = output(pred)

labels = np.arange(7)
train_categories = ['airplane','motorbus','boat','truck','bicycle','motorcycle','seaplane']

clf_report = classification_report(label_test,
                                   y_hat,
                                   labels=labels,
                                   target_names=train_categories,
                                   output_dict=True)

# .iloc[:-1, :] to exclude support
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True)

# %%
# Creating model using the Sequential in tensorflow

def build_model_using_sequential(x_train_scaled,y_train):
  hidden_units1 = 1024
  hidden_units2 = 256
  hidden_units3 = 128
  hidden_units4 = 7
  learning_rate = 0.01
  epp = 100
  batch_s = 128

  model = keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    layers.Conv2D(32, 50, padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(10,10)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(256, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(128, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(16, activation='relu'),
    Dropout(0.2),
    keras.layers.Dense(7, activation=tf.nn.softmax)
  ])
  
  # Compile the Model
  
  model.compile(optimizer=adamax,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  # Model Training

  # train the model
  history = model.fit(train, 
                      label_train, 
                      epochs=epp, 
                      validation_split=0.2,
                      batch_size=batch_s,
                      callbacks=[callback]
                      )
  
  return model,history
  
# build the model
model,history2 = build_model_using_sequential(train, label_train)
plot_history(history2, 'loss')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 3s 117ms/step - loss: 1.9404 - accuracy: 0.2131 - val_loss: 1.8900 - val_accuracy: 0.2194
# Epoch 2/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.7718 - accuracy: 0.2880 - val_loss: 1.6151 - val_accuracy: 0.3078
# Epoch 3/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.5708 - accuracy: 0.3832 - val_loss: 1.3730 - val_accuracy: 0.4405
# Epoch 4/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.3722 - accuracy: 0.4743 - val_loss: 1.1449 - val_accuracy: 0.5238
# Epoch 5/100
# 19/19 [==============================] - 2s 108ms/step - loss: 1.2006 - accuracy: 0.5376 - val_loss: 1.0042 - val_accuracy: 0.6446
# Epoch 6/100
# 19/19 [==============================] - 2s 107ms/step - loss: 1.0852 - accuracy: 0.6006 - val_loss: 0.9797 - val_accuracy: 0.6582
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(test, label_test)

print('Test accuracy:', test_acc)
# Out:
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5502 - accuracy: 0.9050
# Test accuracy: 0.9049586653709412

# %%
pred = model.predict(test)
y_hat = output(pred)

labels = np.arange(7)
train_categories = ['airplane','motorbus','boat','truck','bicycle','motorcycle','seaplane']

clf_report = classification_report(label_test,
                                   y_hat,
                                   labels=labels,
                                   target_names=train_categories,
                                   output_dict=True)

# .iloc[:-1, :] to exclude support
sns.heatmap(pd.DataFrame(clf_report).iloc[:-1, :].T, annot=True)

# %%
# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
#                   loss=tf.keras.losses.CategoricalCrossentropy(),
#                   metrics=[tf.keras.metrics.CategoricalAccuracy(),
#                            tfa.metrics.F1Score(num_classes=7, average='macro'),
#                            tfa.metrics.FBetaScore(beta=2.0, num_classes=7, average='macro')])

# %%
# model = keras.Sequential([
#     layers.Rescaling(1./255),
#     layers.Conv2D(16, 50, padding='same', activation='relu'),
#     layers.MaxPooling2D(),
#     layers.Conv2D(32, 50, padding='same', activation='relu'),
#     layers.MaxPooling2D(),
#     keras.layers.Flatten(),
#     keras.layers.Dense(128, activation=tf.nn.relu),
#     keras.layers.Dense(1, activation=tf.nn.softmax)
# ])

# # Compile the Model

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
#                   loss=tf.keras.losses.CategoricalCrossentropy(),
#                   metrics=[tf.keras.metrics.CategoricalAccuracy(),
#                            tfa.metrics.F1Score(num_classes=7, average='macro'),
#                            tfa.metrics.FBetaScore(beta=2.0, num_classes=7, average='macro')])
# # Model Training

# model.fit(train, label_train, epochs=10, batch_size=128)
